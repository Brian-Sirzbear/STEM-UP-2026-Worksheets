# %% [markdown]
# # Library Entry System <font color='blue'>Version 1.0</font>
# Hello and Welcome to the Entry page for your Code Library! Use this to log any new functions, methods, etc. that you encounter in the labs. To view and edit the results already in your library, go to [this page](https://temple.2i2c.cloud/hub/user-redirect/lab/tree/STEM%20UP%20prototypes/Viewer.ipynb).

# %%
from library_ui import LibraryUI
from library_backend import (
    initialize_library,
    handle_submit
)

initialize_library()

ui = LibraryUI()

ui.display_interface()

ui.btn_submit.on_click(lambda b: handle_submit(ui, b))
# Out:
# HTML(value='\n                <div style="\n                    font-size:20px;\n                    font-weig…
# Dropdown(description='Structure Type:', layout=Layout(width='600px'), options=('Please Select', 'Operation', '…
# Text(value='', description='General Structure:', layout=Layout(width='600px'), placeholder='e.g. print(a, b)',…
# Text(value='', description='Library:', layout=Layout(width='600px'), placeholder='e.g. numpy, datascience, etc…
# Text(value='', description='Number of Arguments:', layout=Layout(width='600px'), placeholder='e.g. 4 (if unlim…
# Textarea(value='', description='Brief Description:', layout=Layout(height='90px', width='600px'), placeholder=…
# Textarea(value='', description='Any additional details:', layout=Layout(height='110px', width='600px'), placeh…
# Text(value='', description='Where did you learn this:', layout=Layout(width='600px'), placeholder='e.g. Lab 2,…
# HTML(value='\n                <div style="\n                    font-size:20px;\n                    font-weig…
# HBox(children=(Text(value='', description='The Input', layout=Layout(width='150px'), placeholder='e.g. a', sty…
# HBox(children=(Text(value='', description='The Input', layout=Layout(width='150px'), placeholder='e.g. b', sty…
# HBox(children=(Text(value='', description='The Input', layout=Layout(width='150px'), placeholder='e.g. c', sty…
# HBox(children=(Text(value='', description='The Input', layout=Layout(width='150px'), placeholder='e.g. d', sty…
# HBox(children=(Text(value='', description='The Input', layout=Layout(width='150px'), placeholder='e.g. e', sty…
# HBox(children=(Text(value='', description='The Input', layout=Layout(width='150px'), placeholder='e.g. f', sty…
# HTML(value='\n                <div style="\n                    color:#888;\n                    font-size:15p…
# Button(button_style='danger', description='Add Entry', icon='plus', style=ButtonStyle())
# Output()
