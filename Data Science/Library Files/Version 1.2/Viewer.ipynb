# %% [markdown]
# # Your Library <font color='blue'>Version 1.2</font>
# This is the page that displays all the entries you have made in your database so far. To add new entries, go to [this page](https://temple.2i2c.cloud/hub/user-redirect/lab/tree/STEM%20UP%20prototypes/New_Entry.ipynb).

# %%
from library_viewer import LibraryViewer

viewer = LibraryViewer()

viewer.display();
